# %%
# !pip install segmentation_models_pytorch
# Out:
# Requirement already satisfied: segmentation_models_pytorch in c:\users\user\anaconda3\lib\site-packages (0.3.3)
# Requirement already satisfied: pillow in c:\users\user\anaconda3\lib\site-packages (from segmentation_models_pytorch) (8.4.0)
# Requirement already satisfied: torchvision>=0.5.0 in c:\users\user\anaconda3\lib\site-packages (from segmentation_models_pytorch) (0.15.2)
# Requirement already satisfied: efficientnet-pytorch==0.7.1 in c:\users\user\anaconda3\lib\site-packages (from segmentation_models_pytorch) (0.7.1)
# Requirement already satisfied: pretrainedmodels==0.7.4 in c:\users\user\anaconda3\lib\site-packages (from segmentation_models_pytorch) (0.7.4)
# Requirement already satisfied: tqdm in c:\users\user\anaconda3\lib\site-packages (from segmentation_models_pytorch) (4.62.3)
# Requirement already satisfied: timm==0.9.2 in c:\users\user\anaconda3\lib\site-packages (from segmentation_models_pytorch) (0.9.2)
# Requirement already satisfied: torch in c:\users\user\anaconda3\lib\site-packages (from efficientnet-pytorch==0.7.1->segmentation_models_pytorch) (2.0.1)
# Requirement already satisfied: munch in c:\users\user\anaconda3\lib\site-packages (from pretrainedmodels==0.7.4->segmentation_models_pytorch) (4.0.0)
# Requirement already satisfied: pyyaml in c:\users\user\anaconda3\lib\site-packages (from timm==0.9.2->segmentation_models_pytorch) (6.0)
# Requirement already satisfied: safetensors in c:\users\user\anaconda3\lib\site-packages (from timm==0.9.2->segmentation_models_pytorch) (0.3.1)
# Requirement already satisfied: huggingface-hub in c:\users\user\anaconda3\lib\site-packages (from timm==0.9.2->segmentation_models_pytorch) (0.16.4)
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\lib\site-packages (from torch->efficientnet-pytorch==0.7.1->segmentation_models_pytorch) (2.11.3)
# Requirement already satisfied: sympy in c:\users\user\anaconda3\lib\site-packages (from torch->efficientnet-pytorch==0.7.1->segmentation_models_pytorch) (1.9)
# Requirement already satisfied: networkx in c:\users\user\anaconda3\lib\site-packages (from torch->efficientnet-pytorch==0.7.1->segmentation_models_pytorch) (2.6.3)
# Requirement already satisfied: typing-extensions in c:\users\user\anaconda3\lib\site-packages (from torch->efficientnet-pytorch==0.7.1->segmentation_models_pytorch) (3.10.0.2)
# Requirement already satisfied: filelock in c:\users\user\anaconda3\lib\site-packages (from torch->efficientnet-pytorch==0.7.1->segmentation_models_pytorch) (3.3.1)
# Requirement already satisfied: requests in c:\users\user\anaconda3\lib\site-packages (from torchvision>=0.5.0->segmentation_models_pytorch) (2.26.0)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\lib\site-packages (from torchvision>=0.5.0->segmentation_models_pytorch) (1.25.0)
# Requirement already satisfied: fsspec in c:\users\user\anaconda3\lib\site-packages (from huggingface-hub->timm==0.9.2->segmentation_models_pytorch) (2021.10.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\user\anaconda3\lib\site-packages (from huggingface-hub->timm==0.9.2->segmentation_models_pytorch) (21.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\user\anaconda3\lib\site-packages (from packaging>=20.9->huggingface-hub->timm==0.9.2->segmentation_models_pytorch) (3.0.4)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from tqdm->segmentation_models_pytorch) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\user\anaconda3\lib\site-packages (from jinja2->torch->efficientnet-pytorch==0.7.1->segmentation_models_pytorch) (1.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests->torchvision>=0.5.0->segmentation_models_pytorch) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests->torchvision>=0.5.0->segmentation_models_pytorch) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests->torchvision>=0.5.0->segmentation_models_pytorch) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\user\anaconda3\lib\site-packages (from requests->torchvision>=0.5.0->segmentation_models_pytorch) (2.0.4)
# Requirement already satisfied: mpmath>=0.19 in c:\users\user\anaconda3\lib\site-packages (from sympy->torch->efficientnet-pytorch==0.7.1->segmentation_models_pytorch) (1.2.1)

# %% [markdown]
# Необходимо подготовить датасет https://www.kaggle.com/olekslu/makeup-lips-segmentation-28k-samples для обучения модели на сегментацию губ
#
# Обучить модель на выбор из segmentation_models_pytorch

# %%
import os
import time

import numpy as np
import pandas as pd

from pathlib import Path
from PIL import Image

from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

import cv2

import torch
from torch import nn, optim
from torch.nn import functional as F
from torch.utils.data import Dataset, DataLoader

import segmentation_models_pytorch as smp
# Out:
# C:\Users\User\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.25.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
dataset_file = 'C:/Users/User/First/PyTorch/lips_segmentation/list.csv'
images_path = 'C:/Users/User/First/PyTorch/lips_segmentation/720p/'
masks_path = 'C:/Users/User/First/PyTorch/lips_segmentation/mask/'

# %%
df = pd.read_csv(dataset_file)
df.head()
# Out:
#             filename  width  height class  xmin  ymin  xmax  ymax  \
# 0  image00000001.jpg   1280     720  Lips   661   394   776   444
# 1  image00000002.jpg   1280     720  Lips   557   336   682   392
# 2  image00000003.jpg   1280     720  Lips   553   369   684   427
# 3  image00000004.jpg   1280     720  Lips   555   351   681   408
# 4  image00000005.jpg   1280     720  Lips   555   351   680   407
#
#                mask
# 0  mask00000001.png
# 1  mask00000002.png
# 2  mask00000003.png
# 3  mask00000004.png
# 4  mask00000005.png

# %%
files_names_list = sorted(os.listdir(images_path))
masks_names_list = sorted(os.listdir(masks_path))
print(f'Images {len(files_names_list)}')
print(f'Masks {len(masks_names_list)}')
# Out:
# Images 28594
# Masks 28540

# %%
#уберем строки с файлами без масок
df = df.loc[df['mask'].isin([i for i in masks_names_list])]
df = df.loc[df['filename'].isin([i for i in files_names_list])]
df.reset_index(drop=True, inplace=True)

# %%
#посмотрим данные
image = cv2.imread(images_path + files_names_list[10], cv2.COLOR_BGR2RGB)
mask = cv2.imread(masks_path + masks_names_list[10], cv2.COLOR_BGR2RGB)

fig, ax = plt.subplots(1, 2, figsize=(10, 10))
ax[0].imshow(image)
ax[0].set_title(f'Изображение {image.shape}')
ax[1].imshow(mask)
ax[1].set_title(f'Маска {mask.shape}')
plt.show()

# %%
data = df[['filename', 'mask']]
data.head()
# Out:
#             filename              mask
# 0  image00000001.jpg  mask00000001.png
# 1  image00000002.jpg  mask00000002.png
# 2  image00000003.jpg  mask00000003.png
# 3  image00000004.jpg  mask00000004.png
# 4  image00000005.jpg  mask00000005.png

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cpu')

# %%
#инициализация модели
segmodel = smp.Linknet(encoder_name = 'resnet34', 
                    encoder_weights = 'imagenet', 
                    in_channels = 3, 
                    classes = 1, # число каналов маски
                    activation = 'sigmoid').to(device)

preprocess_input = smp.encoders.get_preprocessing_fn('resnet34', pretrained='imagenet')

# %%
#класс датасета
class CustomDataset(Dataset):
    def __init__(self, data, preprocessing=None):
        # загружаем данные из датасета
        self.data = data
        self.preprocessing = preprocessing
        self.image_arr = self.data.iloc[:,0] # имена файлов картинок из датасета
        self.label_arr = self.data.iloc[:,1] # имена файлов масок из датасета
        self.data_len = len(self.data.index)
        
    def __len__(self):
        return self.data_len
        
    def __getitem__(self, index):
       # загружаем картинки
        img = cv2.imread(images_path+self.image_arr[index]) 
        img = cv2.cvtColor(cv2.resize(img, (256, 256)), cv2.COLOR_BGR2RGB)
        img = np.asarray(img).astype('float')
        
        if self.preprocessing:
            img = self.preprocessing(img)
            img = torch.as_tensor(img)
        
        else:
            img = torch.as_tensor(img)
            img /= 255.0
        
        img = img.permute(2,0,1)
        
        # загружаем маски
        mask = cv2.imread(masks_path+self.label_arr[index])
        mask = cv2.cvtColor(mask, cv2.COLOR_BGR2RGB)        
        cls_mask = np.where(mask > 50, 1, 0)[:,:,1]
        cls_mask = cls_mask.astype('float')
        cls_mask = cv2.resize(cls_mask, (256, 256))

        masks = [cls_mask]
        masks = torch.as_tensor(masks, dtype=torch.uint8)
        
        
        return (img.float(), masks)

# %%
#разделение датасета на train и test
X_train, X_test = train_test_split(data, test_size=0.3, random_state=42)

#сбрасываем индексы
X_train.reset_index(drop=True,inplace=True)
X_test.reset_index(drop=True,inplace=True)

#создаем датасеты
train_data = CustomDataset(X_train, preprocessing=preprocess_input)
test_data = CustomDataset(X_test, preprocessing=preprocess_input)

#создаем даталодеры
train_data_loader = DataLoader(train_data, batch_size=8, shuffle=True)
test_data_loader = DataLoader(test_data, batch_size=4, shuffle=False)

# %%
#просмотр данных из даталоадера
for img, target in train_data_loader:
    print(img.shape, target.shape)
    print(img[0].min(), img[0].max())
    print(target[0].min(), target[0].max())
    fig, ax = plt.subplots(1, 2, figsize=(15, 6))
    ax[0].imshow(img[0].permute(1, 2, 0))
    ax[1].imshow(target[0].permute(1, 2, 0)[..., 0])
    break
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_78660/973253793.py:38: DeprecationWarning: an integer is required (got type numpy.float64).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   masks = torch.as_tensor(masks, dtype=torch.uint8)
# C:\Users\User\AppData\Local\Temp/ipykernel_78660/973253793.py:38: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\torch\csrc\utils\tensor_new.cpp:248.)
#   masks = torch.as_tensor(masks, dtype=torch.uint8)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# torch.Size([8, 3, 256, 256]) torch.Size([8, 1, 256, 256])
# tensor(-2.0837) tensor(2.6051)
# tensor(0, dtype=torch.uint8) tensor(1, dtype=torch.uint8)

# %%
#определение критерия, метрики и оптимизатора
criterion = smp.utils.losses.DiceLoss()
metrics = [smp.utils.metrics.IoU(),]
optimizer = torch.optim.Adam(params=segmodel.parameters(), lr=0.001)

#определение тренировочных и валидационных эпох
train_epoch = smp.utils.train.TrainEpoch(
    segmodel, 
    loss=criterion, 
    metrics=metrics, 
    optimizer=optimizer,
    device=device,
    verbose=True)

valid_epoch = smp.utils.train.ValidEpoch(
    segmodel, 
    loss=criterion, 
    metrics=metrics,
    device=device,
    verbose=True)

# %%
# обучение модели
num_epochs = 10
linknet_train_iou = []
linknet_valid_iou = []

for i in range(num_epochs):
    print(f'Epoch: {i + 1}')
    train_logs = train_epoch.run(train_data_loader)
    valid_logs = valid_epoch.run(test_data_loader)
    
    linknet_train_iou.append(train_logs['iou_score'])
    linknet_valid_iou.append(valid_logs['iou_score'])
# Out:
# Epoch: 1
# train: 100%|██████████| 2498/2498 [22:24<00:00,  1.86it/s, dice_loss - 0.1351, iou_score - 0.824]
# valid: 100%|██████████| 2141/2141 [08:17<00:00,  4.30it/s, dice_loss - 0.06734, iou_score - 0.8788]
# Epoch: 2
# train: 100%|██████████| 2498/2498 [18:06<00:00,  2.30it/s, dice_loss - 0.03882, iou_score - 0.9269]
# valid: 100%|██████████| 2141/2141 [06:36<00:00,  5.40it/s, dice_loss - 0.03097, iou_score - 0.9407]
# Epoch: 3
# train: 100%|██████████| 2498/2498 [18:09<00:00,  2.29it/s, dice_loss - 0.03644, iou_score - 0.9311]
# valid: 100%|██████████| 2141/2141 [06:32<00:00,  5.46it/s, dice_loss - 0.03069, iou_score - 0.941]
# Epoch: 4
# train: 100%|██████████| 2498/2498 [18:03<00:00,  2.31it/s, dice_loss - 0.0323, iou_score - 0.9383]
# valid: 100%|██████████| 2141/2141 [06:33<00:00,  5.43it/s, dice_loss - 0.04721, iou_score - 0.9152]
# Epoch: 5
# train: 100%|██████████| 2498/2498 [18:35<00:00,  2.24it/s, dice_loss - 0.02743, iou_score - 0.9469]
# valid: 100%|██████████| 2141/2141 [06:41<00:00,  5.34it/s, dice_loss - 0.02835, iou_score - 0.9452]
# Epoch: 6
# train: 100%|██████████| 2498/2498 [18:31<00:00,  2.25it/s, dice_loss - 0.02995, iou_score - 0.943]
# valid: 100%|██████████| 2141/2141 [06:41<00:00,  5.33it/s, dice_loss - 0.03524, iou_score - 0.9326]
# Epoch: 7
# train: 100%|██████████| 2498/2498 [18:32<00:00,  2.24it/s, dice_loss - 0.02677, iou_score - 0.9482]
# valid: 100%|██████████| 2141/2141 [06:51<00:00,  5.21it/s, dice_loss - 0.02391, iou_score - 0.9535]
# Epoch: 8
# train: 100%|██████████| 2498/2498 [18:41<00:00,  2.23it/s, dice_loss - 0.02437, iou_score - 0.9526]
# valid: 100%|██████████| 2141/2141 [06:46<00:00,  5.26it/s, dice_loss - 0.0245, iou_score - 0.9524]
# Epoch: 9
# train: 100%|██████████| 2498/2498 [18:25<00:00,  2.26it/s, dice_loss - 0.02429, iou_score - 0.9528]
# valid: 100%|██████████| 2141/2141 [06:41<00:00,  5.33it/s, dice_loss - 0.02274, iou_score - 0.9557]
# Epoch: 10
# train: 100%|██████████| 2498/2498 [18:43<00:00,  2.22it/s, dice_loss - 0.02268, iou_score - 0.9558]
# valid: 100%|██████████| 2141/2141 [06:58<00:00,  5.12it/s, dice_loss - 0.02212, iou_score - 0.9569]

# %%
x = np.arange(1,11,1)
y = linknet_train_iou
y2 = linknet_valid_iou

plt.plot(x,y,label='IOU_train')
plt.plot(x,y2,label='IOU_val')

plt.title(f"Linknet")   
plt.ylabel('IOU_score')   
plt.xlabel('epochs')   
plt.legend()
plt.show()

# %%
#предсказание модели
for i, data in enumerate(test_data_loader):
    images, labels = data
    images = images.to(device)
    labels = labels.to(device)
    
    outputs = segmodel(images)
    
    f, axarr = plt.subplots(1,3, figsize=(15, 6))

    for j in range(0, 4):
        axarr[0].imshow(outputs.detach().cpu()[i, ].permute(1, 2, 0))
        axarr[0].set_title('Guessed labels')
        
        axarr[1].imshow(labels[i, ].cpu().permute(1, 2, 0))
        axarr[1].set_title('Ground truth labels')
        
        image = images[i].permute(1, 2, 0)
        axarr[2].imshow(image.cpu())
        axarr[2].set_title('Original Images')
        plt.show()
    if i > 2:
        break
